# %%
#

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
df = pd.read_json('./ajam.json')

# %%
df['stars'] = df['ratings'].apply(lambda x: x['stars'])

# %%
len(df[df['stars']>3])
# Out:
# 56
